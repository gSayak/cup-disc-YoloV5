# %% [markdown]
# # Setup
#
# Pull in respective libraries to prepare the notebook environment

# %%
# save the working directory path for later use

import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# clone project repository and install dependencies
# !git clone https://github.com/ultralytics/yolov5.git
# !git clone https://github.com/gSayak/cup-disc-Segmentation.git # clone
# %cd {HOME}/yolov5
# %pip install -r requirements.txt # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15594, done.
# remote: Counting objects: 100% (201/201), done.
# remote: Compressing objects: 100% (145/145), done.
# remote: Total 15594 (delta 95), reused 116 (delta 56), pack-reused 15393
# Receiving objects: 100% (15594/15594), 14.63 MiB | 22.50 MiB/s, done.
# Resolving deltas: 100% (10619/10619), done.
# Cloning into 'cup-disc-Segmentation'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 145 (delta 33), reused 142 (delta 30), pack-reused 0
# Receiving objects: 100% (145/145), 19.00 MiB | 24.98 MiB/s, done.
# Resolving deltas: 100% (33/33), done.
# /content/yolov5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 12.3 MB/s eta 0:00:00
# ...

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-154-gf3ee596 Python-3.9.16 torch-2.0.0+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/107.7 GB disk)

# %%
# !python segment/predict.py --img 320 --weights '/content/cup-disc-Segmentation/weights/weight.pt' --source '/content/fundus.jpg' --name custom-dataset
# Out:
# segment/predict: weights=['/content/cup-disc-Segmentation/weights/weight.pt'], source=/content/fundus.jpg, data=data/coco128.yaml, imgsz=[320, 320], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=custom-dataset, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-154-gf3ee596 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 165 layers, 7401119 parameters, 0 gradients, 25.7 GFLOPs
# image 1/1 /content/fundus.jpg: 256x320 1 cup, 1 disk, 132.3ms
# Speed: 0.4ms pre-process, 132.3ms inference, 24.6ms NMS per image at shape (1, 3, 320, 320)
# Results saved to runs/predict-seg/custom-dataset

# %%
display.Image(filename=f"/content/yolov5/runs/predict-seg/custom-dataset/fundus.jpg", width=600)
